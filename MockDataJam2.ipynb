# %% [markdown]
# # Topic: Measuring the Economic Empowerment of Women

# %% [markdown]
# ## Hypothesis:
# Countries with lower Gender Inequality Index (GII) have a higher economic success compared to those with higher GII.

# %% [markdown]
# ## Datasets:
# https://www.kaggle.com/datasets/gianinamariapetrascu/gender-inequality-index/

# %%
## Description of Variables

# %%
## Methodology:

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %% [markdown]
# ## Graphs of Each Factor:

# %%
df = pd.read_csv("EconomicEmpowermentOfWomen.csv")

# %%
dfr = pd.read_csv("RawDataEcon.csv")

# %%
def HD_Analysis(data):
    HD = df['Human_development'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    HD.plot(kind = "bar")
    plt.title('Human Development')
    plt.xlabel('Human Development Type')
    plt.ylabel('Number of Countries')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


HD_Analysis(df)
plt.show()

# %%
def GII_Analysis(data):
    GII = df['GII(Gender Inequality Index)'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GII.plot(kind = "bar")
    plt.title('Gender Quality Index')
    plt.xlabel('Countries')
    plt.ylabel('Index')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show() 

GII_Analysis(df)
plt.show()

# %%
def MM_Analysis(data):
    Mortality_M = df['Maternal_mortality'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    Mortality_M.plot(kind = "bar")
    plt.title('Maternal Mortality')
    plt.xlabel('Countries')
    plt.ylabel('Ratio (Deaths per 100,000 live births)')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()
    
MM_Analysis(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def ABR_Analysis(data):
    ABR = df['Adolescent_birth_rate'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    ABR.plot(kind = "bar")
    plt.title('Adolescent Birth Rate')
    plt.xlabel('Countries')
    plt.ylabel('(Adolescent birth rate (births per 1,000 women ages 15–19)')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()

ABR_Analysis(df)
plt.show()

# %%
def ParSeats_Analysis(data):
    PS = df['Seats_parliament'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    PS.plot(kind = "bar")
    plt.title('Parliament Seats')
    plt.xlabel('Countries')
    plt.ylabel('Rate')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()

ParSeats_Analysis(df)
plt.show()

# %%
def FSE_Analysis(data):
    GII = df['F_secondary_educ'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GII.plot(kind = "bar")
    plt.title('Female Secondary Education level')
    plt.xlabel('Countries')
    plt.ylabel('Percentage ages 25 and older')      
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


FSE_Analysis(df)
plt.show()

# %%
 def MSE_Analysis(data):
    GII = df['M_secondary_educ'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GII.plot(kind = "bar")
    plt.title('Male secondary education')
    plt.xlabel('Countries')
    plt.ylabel('Percentage ages 25 and older')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()

MSE_Analysis(df)
plt.show()

# %%
def FLF_Analysis(data):
    GII = df['F_Labour_force'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GII.plot(kind = "bar")
    plt.title('Female - Labor force participation rate')
    plt.xlabel('Countries')
    plt.ylabel('Percentages ages 15 and over')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()

FLF_Analysis(df)
plt.show()

# %%
def MLF_Analysis(data):
    MLF = df['M_Labour_force'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    MLF.plot(kind = "bar")
    plt.title('Male - Labor force participation rate')
    plt.xlabel('Countries')
    plt.ylabel('Percentages')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()
    
MLF_Analysis(df)
plt.show()

# %%
def DEN_Analysis(data):
    GII = df['Density'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GII.plot(kind = "bar")
    plt.title('Density (P/Km^2)')
    plt.xlabel('Countries')
    plt.ylabel('Density')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()

DEN_Analysis(df)
plt.show()

# %%
def MN_Analysis(data):
    Migrant_Net = df['Migrants  (net)'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    Migrant_Net.plot(kind = "bar")
    plt.title('Net Migrant Count')
    plt.xlabel('Rate')
    plt.ylabel('Count')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


MN_Analysis(df)
plt.show()

# %%
def FR_Analysis(data):
    Fert_Rate = df['Fert.  Rate'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    Fert_Rate.plot(kind = "bar")
    plt.title('Fertility Rate')
    plt.xlabel('Rate')
    plt.ylabel('Count')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


FR_Analysis(df)
plt.show()

# %%
def MA_Analysis(data):
    Med_Age = df['Med.  Age'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    Med_Age.plot(kind = "bar")
    plt.title('Median Age')
    plt.xlabel('Age')
    plt.ylabel('Count')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


MA_Analysis(df)
plt.show()

# %%
def WS_Analysis(data):
    World_S = df['World  Share'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    World_S.plot(kind = "bar")
    plt.title('World Share')
    plt.xlabel('Share')
    plt.ylabel('Count')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


WS_Analysis(df)
plt.show()

# %%
def Pop_Analysis(data):
    Pop = df['Population  (2022)'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    Pop.plot(kind = "bar")
    plt.title('Total Population in 2022')
    plt.xlabel('Countries')
    plt.ylabel('Population (2022)')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()


Pop_Analysis(df)
plt.show()

# %%
def GDP_PC_Analysis(data):
    GDP_PC = df['GDP   per capita'].value_counts().sort_index()
    plt.figure(figsize = (10,6))
    GDP_PC.plot(kind = "bar")
    plt.title('GDP per capita')
    plt.xlabel('Countries')
    plt.ylabel('Index')
    plt.xticks(rotation = 0)
    plt.grid(axis = 'y', linestyle='--', alpha = 0.7)
    plt.show()
    
GDP_PC_Analysis(df)
plt.show()

# %% [markdown]
# ### Making Predictions With Our K Nearest Neighbors Algorithm

# %%
import pandas #fixed
from sklearn.impute import KNNImputer

dfr.replace('', pd.NA, inplace=True)

imputer = KNNImputer(n_neighbors=3)

df_full = pd.DataFrame(imputer.fit_transform(dfr), columns=dfr.columns)

display(dfr)
# Out:
#      GII(Gender Inequality Index)   Rank  Maternal_mortality  \
# 0                           0.018    3.0                 5.0
# 1                           0.016    2.0                 2.0
# 2                           0.043    8.0                 4.0
# 3                             NaN    NaN                 NaN
# 4                           0.073   19.0                 6.0
# ..                            ...    ...                 ...
# 190                         0.587  150.0              1150.0
# 191                           NaN    NaN                89.0
# 192                           NaN    NaN                 NaN
# 193                           NaN    NaN                 NaN
# 194                           NaN    NaN               829.0
#
#      Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                      2.2              39.8              96.9
# 1                      2.3              45.0              99.1
# ...

# %%
display(df_full)
# Out:
#      GII(Gender Inequality Index)        Rank  Maternal_mortality  \
# 0                        0.018000    3.000000            5.000000
# 1                        0.016000    2.000000            2.000000
# 2                        0.043000    8.000000            4.000000
# 3                        0.217000   53.333333           17.000000
# 4                        0.073000   19.000000            6.000000
# ..                            ...         ...                 ...
# 190                      0.587000  150.000000         1150.000000
# 191                      0.315000   75.333333           89.000000
# 192                      0.198333   49.666667           12.333333
# 193                      0.454000  112.666667          127.666667
# 194                      0.454000  112.666667          829.000000
#
#      Adolescent_birth_rate  Seats_parliament  F_secondary_educ  \
# 0                      2.2         39.800000         96.900000
# ...

# %% [markdown]
# # Regression Analysis :

# %%
print(df_full.columns)
# Out:
# Index(['GII(Gender Inequality Index)', 'Rank', 'Maternal_mortality',
#        'Adolescent_birth_rate', 'Seats_parliament', 'F_secondary_educ',
#        'M_secondary_educ', 'F_Labour_force', 'M_Labour_force', 'Population',
#        'Yearly Change', 'Net Change', 'Density', 'Land Area ',
#        'Migrants  (net)', 'Fert.  Rate', 'Med.  Age', 'Urban  Pop %',
#        'World  Share', 'GDP  (nominal, 2022)', 'GDP   growth',
#        'Population  (2022)', 'GDP   per capita', 'Share of  World GDP'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

x = df_full[['GII(Gender Inequality Index)', 'Rank', 'Maternal_mortality',
       'Adolescent_birth_rate', 'Seats_parliament', 'F_secondary_educ',
       'M_secondary_educ', 'F_Labour_force', 'M_Labour_force', 'Population',
       'Yearly Change', 'Net Change', 'Density', 'Land Area ',
       'Migrants  (net)', 'Fert.  Rate', 'Med.  Age', 'Urban  Pop %',
       'World  Share', 'GDP  (nominal, 2022)', 'GDP   growth',
       'Population  (2022)', 'GDP   per capita', 'Share of  World GDP']]


y = df_full["GDP   per capita"]

model = LinearRegression()

model.fit(x,y)

coefficients = model.coef_
intercept = model.intercept_

print("Coefficients:", coefficients)
print("Intercept:", intercept)
# Out:
# Coefficients: [-2.36052938e-10 -9.36365676e-13  1.24695466e-14  1.19845804e-12
#  -4.54999399e-12  2.87968494e-12 -3.05070160e-12  5.07022657e-13
#  -1.18925035e-12 -8.09206730e-17 -4.64806994e-10  2.37435603e-16
#   1.07307309e-15 -2.09803450e-16 -1.15550257e-17  7.08457444e-12
#   6.02171902e-14 -3.46067681e-11 -1.79745700e-10  3.97046694e-23
#  -5.09909344e-11  8.08999279e-17  1.00000000e+00  2.06902183e-10]
# Intercept: 3.5652192309498787e-10

# %%
'GII(Gender Inequality Index)',
'Rank', 'Maternal_mortality',
'Adolescent_birth_rate', 
'Seats_parliament', '
F_secondary_educ',
'M_secondary_educ', 
'F_Labour_force', 
'M_Labour_force', 
'Population',
'Yearly Change', 
'Net Change',
'Density',
'Land Area ',
'Migrants  (net)',
'Fert.  Rate',
'Med.  Age', 
'Urban  Pop %',
'World  Share', 
'GDP  (nominal, 2022)', 
'GDP   growth',
'Population  (2022)',
'GDP   per capita',
'Share of  World GDP'

# %%
import statsmodels.api as sm

X = sm.add_constant(df_full[['GII(Gender Inequality Index)','Seats_parliament','F_secondary_educ','M_secondary_educ','F_Labour_force','M_Labour_force','Density','Land Area ','Med.  Age','Urban  Pop %','Maternal_mortality']])


y = df_full['GDP   per capita']

model = sm.OLS(y, X)

results = model.fit()

print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       GDP   per capita   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.391
# Method:                 Least Squares   F-statistic:                     12.30
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):           3.35e-17
# Time:                        12:13:44   Log-Likelihood:                -2219.2
# No. Observations:                 195   AIC:                             4462.
# Df Residuals:                     183   BIC:                             4502.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                        -2.925e+04   2.55e+04     -1.147      0.253   -7.95e+04     2.1e+04
# ...

# %%
# Out:
# 4488.408462757468

# %% [markdown]
# ## Very low r^2 so going to check for multicollinearity

# %%
correlation_matrix = df_full.corr()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
## Conclusions:

# %%
## Recommendations:
